# %%
import requests
import pandas as pd
import re
import numpy as np

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

rootPath = '/Users/khazi/Documents/Learning/Aufgabe_Data_Engineer'

# %% [markdown]
# ## Task 1.d : Automate the read process with period and MMSI

# %%
MMSI_input       = input('Enter the MMSI\r\n')
Period_input     = int(input('Enter 1 for Hourly Period and 2 for Daily \r\n'))

if Period_input == 1:
    period = "hourly"
else:
    period = "daily"
url = "https://services.marinetraffic.com/api/exportvesseltrack/0260e3f1ff1fae54305a7516ac1ec191b6caacaf/v:3/period:" + str(period) + "/days:2/protocol:csv/mmsi:" + str(MMSI_input)
# Out:
# Enter the MMSI
# 269057489
# Enter 1 for Hourly Period and 2 for Daily
# 2

# %% [markdown]
# ### Task 1.a Retrieve data from for Vessels

# %%
#response = requests.get("https://services.marinetraffic.com/api/exportvesseltrack/0260e3f1ff1fae54305a7516ac1ec191b6caacaf/v:3/period:hourly/days:2/protocol:csv/mmsi:269057489")
#response2 = requests.get("https://services.marinetraffic.com/api/exportvesseltrack/0260e3f1ff1fae54305a7516ac1ec191b6caacaf/v:3/period:hourly/days:2/protocol:csv/mmsi:211284350")
#url_content = response.content
#url_content_2 = response2.content

# %%
csv_269057489 = b'MMSI, IMO, STATUS, SPEED, LON, LAT, COURSE, HEADING, TIMESTAMP, SHIP_ID\r\n211284350,9173317,5,0,8.494795,53.340740,319,195,2021-08-01T20:33:00,132404\r\n211284350,9173317,5,0,8.494815,53.340740,319,195,2021-08-01T21:33:00,132404\r\n211284350,9173317,5,0,8.494842,53.340780,319,195,2021-08-01T22:33:00,132404\r\n211284350,9173317,5,0,8.494813,53.340720,319,195,2021-08-01T23:33:00,132404\r\n211284350,9173317,5,0,8.494843,53.340720,319,195,2021-08-02T00:33:00,132404\r\n211284350,9173317,5,0,8.494808,53.340730,319,195,2021-08-02T01:33:00,132404\r\n211284350,9173317,5,0,8.494793,53.340770,319,195,2021-08-02T02:33:00,132404\r\n211284350,9173317,5,0,8.494795,53.340770,319,195,2021-08-02T03:33:00,132404\r\n211284350,9173317,5,0,8.494793,53.340700,109,194,2021-08-02T04:33:00,132404\r\n211284350,9173317,5,1,8.494795,53.340720,106,194,2021-08-02T05:33:00,132404\r\n211284350,9173317,5,0,8.494819,53.340740,103,194,2021-08-02T06:33:00,132404\r\n211284350,9173317,5,0,8.494808,53.340750,104,195,2021-08-02T07:34:00,132404\r\n211284350,9173317,5,0,8.494806,53.340760,104,195,2021-08-02T08:34:00,132404\r\n211284350,9173317,5,0,8.494800,53.340750,104,194,2021-08-02T09:34:00,132404\r\n211284350,9173317,5,0,8.494780,53.340710,287,195,2021-08-02T10:34:00,132404\r\n211284350,9173317,5,0,8.494780,53.340750,102,194,2021-08-02T11:34:00,132404\r\n211284350,9173317,0,146,8.499545,53.375480,355,355,2021-08-02T12:33:00,132404\r\n211284350,9173317,0,131,8.526888,53.582500,330,330,2021-08-02T13:33:00,132404\r\n211284350,9173317,0,108,8.289610,53.718510,302,302,2021-08-02T14:32:00,132404\r\n211284350,9173317,0,120,8.120520,53.857980,1,357,2021-08-02T15:32:00,132404\r\n211284350,9173317,0,131,8.090533,53.969920,65,59,2021-08-02T16:31:00,132404\r\n211284350,9173317,0,129,8.444650,53.977790,104,101,2021-08-02T17:31:00,132404\r\n
df_500.head()
# Out:
# 0       MMSI  IMO  STATUS  SPEED       LON        LAT  COURSE  HEADING  \
# 1  269057489    0       0      0  6.984600  50.972020      65      178
# 2  269057489    0       0      0  6.984607  50.972010      65      178
# 3  269057489    0       0      0  6.984598  50.972040      65      178
# 4  269057489    0       0      0  6.984601  50.972020      65      178
# 5  269057489    0       0      0  6.984600  50.972020      65      178
#
# 0            TIMESTAMP  SHIP_ID
# 1  2021-07-31T17:30:00   330455
# 2  2021-07-31T18:32:00   330455
# 3  2021-07-31T19:32:00   330455
# 4  2021-07-31T20:36:00   330455
# 5  2021-07-31T21:36:00   330455

# %%
df_489 = pd.DataFrame([x.split(",") for x in csv_269057489])
df_489.columns = df_489.iloc[0]
df_489 = df_489[1:]
df_489.to_csv('df_269057489.csv', index=False)
df_489.head()
# Out:
# 0     b'MMSI      IMO  STATUS  SPEED       LON        LAT  COURSE  HEADING  \
# 1  211284350  9173317       5      0  8.494795  53.340740     319      195
# 2  211284350  9173317       5      0  8.494815  53.340740     319      195
# 3  211284350  9173317       5      0  8.494842  53.340780     319      195
# 4  211284350  9173317       5      0  8.494813  53.340720     319      195
# 5  211284350  9173317       5      0  8.494843  53.340720     319      195
#
# 0            TIMESTAMP  SHIP_ID
# 1  2021-08-01T20:33:00   132404
# 2  2021-08-01T21:33:00   132404
# 3  2021-08-01T22:33:00   132404
# 4  2021-08-01T23:33:00   132404
# 5  2021-08-02T00:33:00   132404

# %% [markdown]
# ### rearrange and rename columns for csv_269057500

# %%
df2_500 = df_500.copy()
df2_500= df2_500.rename(columns={' SHIP_ID': 'SHIP', ' SPEED' : 'SPEED',' LON': 'LON',' LAT':'LAT', ' TIMESTAMP':'TIMESTAMP'})
df2_500= df2_500[['SHIP', 'TIMESTAMP', 'SPEED','LON','LAT']]
df2_500.head()
# Out:
# 0    SHIP            TIMESTAMP SPEED       LON        LAT
# 1  330455  2021-07-31T17:30:00     0  6.984600  50.972020
# 2  330455  2021-07-31T18:32:00     0  6.984607  50.972010
# 3  330455  2021-07-31T19:32:00     0  6.984598  50.972040
# 4  330455  2021-07-31T20:36:00     0  6.984601  50.972020
# 5  330455  2021-07-31T21:36:00     0  6.984600  50.972020

# %% [markdown]
# ### rearrange and rename columns for csv_269057489

# %%
df2_489 = df_489.copy()
df2_489= df2_489.rename(columns={' SHIP_ID': 'SHIP', ' SPEED' : 'SPEED',' LON': 'LON',' LAT':'LAT', ' TIMESTAMP':'TIMESTAMP'})
df2_489= df2_489[['SHIP', 'TIMESTAMP', 'SPEED','LON','LAT']]
df2_489.head()
# Out:
# 0    SHIP            TIMESTAMP SPEED       LON        LAT
# 1  132404  2021-08-01T20:33:00     0  8.494795  53.340740
# 2  132404  2021-08-01T21:33:00     0  8.494815  53.340740
# 3  132404  2021-08-01T22:33:00     0  8.494842  53.340780
# 4  132404  2021-08-01T23:33:00     0  8.494813  53.340720
# 5  132404  2021-08-02T00:33:00     0  8.494843  53.340720

# %%
#df2_489.info() 
#df2_500.info()

# %% [markdown]
# ### Task 1.b Read the position_data.csv

# %%
pos_data = pd.read_csv('position_data.csv')
pos_data.TIMESTAMP = pd.to_datetime(pos_data.TIMESTAMP)
#pos_data.info()

# %% [markdown]
# ### Task 1.c merge csv file with the df_500 and df_489

# %%
def tstamp_column(tem):
    temp = tem.split('T')
    return(pd.to_datetime(temp[0] + ' ' + temp[1]))

df2_500.TIMESTAMP = df2_500.TIMESTAMP.apply(tstamp_column)
df2_489.TIMESTAMP = df2_489.TIMESTAMP.apply(tstamp_column)

# %%
# merge both the data frames
df_concat = pd.concat([pos_data, df2_500]).reset_index(drop=True)
df_concat_2 = pd.concat([pos_data, df2_489]).reset_index(drop=True)
#df_concat

# %% [markdown]
# # Task2 Webscraping

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.finning.com/en_CA/products/new/power-systems/electric-power-generation/diesel-generator-sets/1000001866.html'
requiredData = ['Minimum Rating', 'Maximum Rating', 'Emissions/Fuel Strategy', 'Voltage', 'Frequency', 'Speed']
home_url = 'https://www.finning.com/en_CA/products/new/power-systems/electric-power-generation/diesel-generator-sets.html'

# %%
req = requests.get(home_url)
soup = BeautifulSoup(req.content, 'lxml')

# %%
product_list = soup.find_all('div', class_='product-card product-family grid__4x25')
product_links = []
for item in product_list:
    for link in item.find_all('a', href=True):
        product_links.append('https://www.finning.com/' + link['href'])

# %% [markdown]
# #### This might take upto 2 mins

# %%
df_blank= pd.DataFrame(columns=['Minimum Rating', 'Maximum Rating', 'Voltage', 'Frequency', 'Speed'])

for prod_link in product_links:
    req_spec = requests.get(prod_link)
    soup_specs = BeautifulSoup(req_spec.content, 'lxml')
    specs_list = soup_specs.find_all('div', class_='spec spaced-spec')

    data = []
    for i in [0,1,3,4,5]:
        feature = re.search(r'(<strong>)(.+)(</strong>)', str(specs_list[i]))
        value = re.search(r'("unit unit-us">)(.+)(<)', str(specs_list[i]))
        data.append(value.group(2))

    df_blank = df_blank.append({'Minimum Rating': data[0], 'Maximum Rating':data[1], 'Voltage':data[2], 'Frequency': data[3], 'Speed':data[4] }, ignore_index=True)

# %%
df_blank

# %% [markdown]
# ### Extract valid information from the dataframe

# %%
df_motor = df_blank.copy()
df_motor = df_motor.rename(columns = {'Minimum Rating' : 'Minimum_Rating_in_eKW', 'Maximum Rating' : 'Maximum_Rating_in_eKW', 'Voltage': 'Voltage_in_Volts', 'Frequency': 'Frequency_in_Hz', 'Speed': 'Speed_in_rpm'})

def extract_min_max_rating(temp):
    value = re.search(r"\d+", temp)
    return(value.group(0))

def extract_volt(temp):
    if re.search(r".*(Volts$|volts$)", str(temp)):
        if re.search(r"([0-9]+)\s?(?=(to|-))", temp):
            value = re.search(r"([0-9]+)\s?(?=(to|-))", temp)
            return(value.group(1))
        else:
            value = re.search(r"(.*)(Volts$|volts$)", str(temp))
            return(value.group(1))

    elif re.search(r".*([0-9]+$)", str(temp)):
        if re.search(r"([0-9]+)\s(?=to)", temp):
            value = re.search(r"([0-9]+)\s(?=to)", temp)
            return(value.group(1))
        else:
            value = re.search(r"(.*)(\d+$)", str(temp))
            return(value.group(1))
    else:
        return(np.NaN)
    
def extract_freq(temp):
    if re.search(r".*(Hz$)", temp):
        if re.search(r"([0-9]+)\s(?=or)", temp):
            value = re.search(r"([0-9]+)\s(?=or)", temp)
            return(value.group(1))
        else:
            value = re.search(r"(.*)(Hz$)", temp)
            return(value.group(1))
        
    elif re.search(r".*([0-9]+$)", temp):
        value = re.search(r"(\d+)\s(?=Hz)", temp)
        return(value.group(1))  
    else:
        return(np.NaN)

def extract_speed(temp):
    if re.search(r".*(rpm$|RPM$)", temp):
        if re.search(r"([0-9]+)\s(?=or)", temp):
            value = re.search(r"([0-9]+)\s(?=or)", temp)
            return(value.group(1))
        else:
            value = re.search(r"(.*)(rpm$|RPM$)", temp)
            return(value.group(1))
    elif re.search(r"(\d+)\s(?=(rpm$|RPM$))", temp):
        value = re.search(r"(\d+)\s(?=(rpm$|RPM$))", temp)
        return(value.group(1))  
    else:
        return(np.NaN)

# %%
df_motor.Minimum_Rating_in_eKW = df_motor.Minimum_Rating_in_eKW.apply(extract_min_max_rating)
df_motor.Maximum_Rating_in_eKW = df_motor.Maximum_Rating_in_eKW.apply(extract_min_max_rating)

df_motor.Frequency_in_Hz = df_motor.Frequency_in_Hz.apply(extract_freq)
df_motor.Voltage_in_Volts = df_motor.Voltage_in_Volts.apply(extract_volt)
df_motor.Speed_in_rpm = df_motor.Speed_in_rpm.apply(extract_speed)

# %%
df_motor
# Out:
#    Minimum_Rating_in_eKW Maximum_Rating_in_eKW Voltage_in_Volts  \
# 0                    830                  1000              220
# 1                    830                  1000              220
# 2                    320                   400              208
# 3                   1230                  1500              220
# 4                   1650                  2500              220
# 5                   1230                  1500              220
# 6                   2500                  2750             4160
# 7                    114                   175              208
# 8                    455                   500              208
# 9                    725                   800              208
# 10                   830                  1000              220
# 11                   550                   600              480
# 12                  1640                  2250              220
# 13                  1735                  2600             3000
# ...

# %% [markdown]
# ### Task 2.b extend the existing database with this data, i.e. df2_500 and df2_500

# %%
df2_500_and_df_motot_concat = pd.concat([df2_500, df_motor], axis=1)
df2_489_and_df_motot_concat = pd.concat([df2_489, df_motor], axis=1)

# %%
df2_500_and_df_motot_concat.head()
# Out:
#      SHIP            TIMESTAMP SPEED       LON        LAT  \
# 0     NaN                  NaN   NaN       NaN        NaN
# 1  330455  2021-07-31T17:30:00     0  6.984600  50.972020
# 2  330455  2021-07-31T18:32:00     0  6.984607  50.972010
# 3  330455  2021-07-31T19:32:00     0  6.984598  50.972040
# 4  330455  2021-07-31T20:36:00     0  6.984601  50.972020
#
#   Minimum_Rating_in_eKW Maximum_Rating_in_eKW Voltage_in_Volts  \
# 0                   830                  1000              220
# 1                   830                  1000              220
# 2                   320                   400              208
# 3                  1230                  1500              220
# 4                  1650                  2500              220
#
#   Frequency_in_Hz Speed_in_rpm
# 0              50         1500
# 1              50         1500
# 2             60         1800
# 3              50         1500
# 4             60         1800

# %% [markdown]
# # Task3 : SQL Query

# %%
import pandas as pd
import pandasql as ps

# %%
pos_data = pd.read_csv("position_data.csv")
ship_owner = pd.read_csv('ships_per_owner.csv')
ship_eng2 = pd.read_csv("ship_engines.csv")
#pos_data.columns

# %% [markdown]
# ### Task 3.a What is the average speed per ship per day across all ships?

# %%
q1 = """SELECT DATE(TIMESTAMP) as DATE, SHIP, AVG(SPEED) as AVG_SPEED_PER_DAY from pos_data GROUP BY SHIP, DATE(TIMESTAMP)"""
#print(ps.sqldf(q1, locals()))

# %%
#q3 = """SELECT SHIP, AVG(SPEED) as AVERAGE_SPEED from pos_data GROUP BY SHIP"""
#print(ps.sqldf(q3, locals()))

# %% [markdown]
# ### Task 3.b Average Nauticals miles per ship owner

# %%
q3 = """SELECT so.viking, ((pd.LAT + pd.LON)*pd.SPEED) as NMILES
        FROM pos_data pd
        JOIN ship_owner so ON so.viking = pd.SHIP
        WHERE TIME(TIMESTAMP) BETWEEN '12:00:00' AND '14:00:00'
        GROUP BY so.viking
        """
print(ps.sqldf(q3, locals()))
# Out:
#      viking      NMILES
# 0  Ship_495    0.000000
# 1  Ship_584  227.356274
# 2  Ship_642  666.776775
# 3  Ship_733   45.111630

# %%
q3 = """SELECT so.aztec, ((pd.LAT + pd.LON)*pd.SPEED) as NMILES
        FROM pos_data pd
        JOIN ship_owner so ON so.aztec = pd.SHIP
        WHERE TIME(TIMESTAMP) BETWEEN '12:00:00' AND '14:00:00'
        GROUP BY so.aztec
        """
print(ps.sqldf(q3, locals()))
# Out:
#       aztec      NMILES
# 0  Ship_454  622.095820
# 1  Ship_463   54.962381

# %%
q3 = """SELECT so.roman, ((pd.LAT + pd.LON)*pd.SPEED) as NMILES
        FROM pos_data pd
        JOIN ship_owner so ON so.roman = pd.SHIP
        WHERE TIME(TIMESTAMP) BETWEEN '12:00:00' AND '14:00:00'
        GROUP BY so.roman
        """

print(ps.sqldf(q3, locals()))
# Out:
#       roman      NMILES
# 0  Ship_322  889.969821
# 1  Ship_417  699.460252
# 2  Ship_707  592.761944

# %%
q3 = """SELECT so.aegyptian, ((pd.LAT + pd.LON)*pd.SPEED) as NMILES
        FROM pos_data pd
        JOIN ship_owner so ON so.aegyptian = pd.SHIP
        WHERE TIME(TIMESTAMP) BETWEEN '12:00:00' AND '14:00:00'
        GROUP BY so.aegyptian
        """

print(ps.sqldf(q3, locals()))
# Out:
#   aegyptian      NMILES
# 0  Ship_337  176.071995

# %%
q3 = """SELECT so.amazon, ((pd.LAT + pd.LON)*pd.SPEED) as NMILES
        FROM pos_data pd
        JOIN ship_owner so ON so.amazon = pd.SHIP
        WHERE TIME(TIMESTAMP) BETWEEN '12:00:00' AND '14:00:00'
        GROUP BY so.amazon
        """

print(ps.sqldf(q3, locals()))
# Out:
# Empty DataFrame
# Columns: [amazon, NMILES]
# Index: []

# %% [markdown]
# ### Task 3.c Show the ranking of engine types (engine_name) relative to the maximum speed shown.

# %%
q3 = """SELECT pd.SHIP, MAX(pd.SPEED) as MAX_SPEED , engine2_name as ENGINE_GROUP2 from pos_data pd 
        JOIN ship_eng2 se ON se.ship_name = pd.SHIP GROUP BY SHIP"""
print(ps.sqldf(q3, locals()))
# Out:
#        SHIP  MAX_SPEED       ENGINE_GROUP2
# 0  Ship_322         11  C18 (60 HZ) TIER 4
# 1  Ship_337         11         C32 (60 HZ)
# 2  Ship_417         11         C32 (60 HZ)
# 3  Ship_454         11         C32 (60 HZ)
# 4  Ship_463         11                None
# 5  Ship_495         11  C18 (60 HZ) TIER 4
# 6  Ship_584         11         C32 (60 HZ)
# 7  Ship_642         11  C18 (60 HZ) TIER 4
# 8  Ship_707         11         C18 (60 HZ)
# 9  Ship_733         11                None

# %%
#q3 = """SELECT pd.SHIP, MAX(pd.SPEED) as MAX_SPEED , engine1_name as ENGINE_GROUP1, engine2_name as ENGINE_GROUP2, 
#        engine3_name as ENGINE_GROUP3 from pos_data pd 
#        JOIN ship_eng2 se ON se.ship_name = pd.SHIP GROUP BY SHIP"""
#print(ps.sqldf(q3, locals()))
